# %%
print('Hello World')
# Out:
# Hello World

# %%
#%pip install requests
# Out:
# Collecting requests
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.2-cp312-cp312-macosx_10_13_universal2.whl.metadata (35 kB)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rajeshrampure/Desktop/Project/Analytics-API/venv/lib/python3.12/site-packages (from requests) (3.10)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rajeshrampure/Desktop/Project/Analytics-API/venv/lib/python3.12/site-packages (from requests) (2025.6.15)
# Downloading requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.2-cp312-cp312-macosx_10_13_universal2.whl (199 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Installing collected packages: urllib3, charset_normalizer, requests
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [requests]
# Successfully installed charset_normalizer-3.4.2 requests-2.32.4 urllib3-2.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
path = 'health'
base_url = 'http://localhost:8000'

endpoint = f'{base_url}/{path}'
print(f'Endpoint: {endpoint}')
# Out:
# Endpoint: http://localhost:8000/health

# %%
import requests

# %%
response = requests.get(endpoint)
print(f'Status Code: {response.status_code}')
print(f'Response: {response.ok}')
# Out:
# Status Code: 200
# Response: True
